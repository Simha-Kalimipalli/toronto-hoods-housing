# %%
https://www.sktime.net/en/stable/user_guide.html
# Out:
#   File "<ipython-input-1-8a1a787b8981>", line 1
#     https://www.sktime.net/en/stable/user_guide.html
#           ^
# SyntaxError: invalid syntax

# %%
https://ts.gluon.ai/stable/
