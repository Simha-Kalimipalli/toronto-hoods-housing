# %%
import seaborn as sns
#trn = trn.dropna()

#sns.pairplot(trn, hue='Owner')

#-----
# !pip install umap-learn
#import umap-learn
#reducer = umap.UMAP()

#umap-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

trn  = trn[
    [
        "age_0_14", "age_15_24"
    ]
].values
scaled_penguin_data = StandardScaler().fit_transform(penguin_data)
# Out:
# ...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-36a8fc0950a9> in <module>()
#      19 trn  = trn[
#      20     [
# ---> 21         "age_0_14", "age_15_24"
#      22     ]
#      23 ].values
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
x = data["mmcom_driver"]
y = data["comu_dur_median"]
plt.plot(x, y, "o", color='black');
plt.title("amount of drivers vs commute timing")
plt.show()
plt.clf()


x = data["mmcom_public"]
y = data["comu_dur_median"]
plt.plot(x, y, "o", color='black');
plt.title("amount of public transit riders vs commute timing")
plt.show()
plt.clf()

# %%
data = pd.read_csv("drive/My Drive/development/MachineLearning/Neighborhoods/neighborhood_toronto.csv", encoding='utf-8')
nam = list(data.head(0))
data = data.drop(data.columns[[0]], axis=1)  # df.columns is zero-based pd.Index

from sklearn.preprocessing import StandardScaler
###features = ['sepal length', 'sepal width', 'petal length', 'petal width']

features  = nam
# Separating out the features
#x = data.loc[:, features].values

#@print(x)
# Separating out the target
#y = data.loc[:,['target']].values
# Standardizing the features
x = StandardScaler().fit_transform(data)


from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-ecc948f4b058> in <module>()
#      19 from sklearn.decomposition import PCA
#      20 pca = PCA(n_components=2)
# ---> 21 principalComponents = pca.fit_transform(x)
#      22 principalDf = pd.DataFrame(data = principalComponents
#      23              , columns = ['principal component 1', 'principal component 2'])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     405         C-ordered array, use 'np.ascontiguousarray'.
#     406         """
# --> 407         U, S, Vt = self._fit(X)
#     408         U = U[:, : self.n_components_]
#     409
#
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     429
#     430         X = self._validate_data(
# ...
